# %%
import pandas as pd

# %%
(pd.read_csv("train_input_7.csv").iloc[:,1:] / 10000).to_csv("train_input_7_.csv")

# %%
(pd.read_csv("train_output_7.csv").iloc[:,1:] / 10000).to_csv("train_output_7_.csv")

# %%
(pd.read_csv("val_output_7.csv").iloc[:,1:] / 10000).to_csv("val_output_7_.csv")

# %%
(pd.read_csv("val_input_7.csv").iloc[:,1:] / 10000).to_csv("val_input_7_.csv")
